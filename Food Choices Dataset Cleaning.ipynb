# %% [markdown]
# # Import Library

# %%
#For basic operations.
import numpy as np
import pandas as pd

#For data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read The Dataset

# %%
#Read the dataset.
data = pd.read_csv('food_coded.csv')

#Check the shape of the dataset
data.shape
# Out:
# (125, 61)

# %% [markdown]
# # Check The Head Of The Dataset

# %%
#Check the head of the dataset
data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %% [markdown]
# # Check Missing Values

# %%
#Check missing values.
data.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# breakfast            0
# calories_chicken     0
# calories_day        19
#                     ..
# type_sports         21
# veggies_day          0
# vitamins             0
# waffle_calories      0
# weight               2
# Length: 61, dtype: int64

# %%
#Impute misssing values.
data['GPA'] = data['GPA'].fillna(data['GPA'].mode()[0])
data['calories_day'] = data['calories_day'].fillna(data['calories_day'].mean())
data['type_sports'] = data['type_sports'].fillna(data['type_sports'].mode()[0])
data['weight'] = data['weight'].fillna(data['weight'].mode()[0])

#Check the missing value again.
data.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# breakfast           0
# calories_chicken    0
# calories_day        0
#                    ..
# type_sports         0
# veggies_day         0
# vitamins            0
# waffle_calories     0
# weight              0
# Length: 61, dtype: int64

# %% [markdown]
# # Check For Outliers

# %%
#Check for outliers.
plt.rcParams['figure.figsize'] = (12,3)
plt.style.use('fivethirtyeight')

plt.subplot(1,3,1)
sns.boxplot(data['calories_day'])
plt.show()

# %%
data['calories_day']
# Out:
# 0      3.028302
# 1      3.000000
# 2      4.000000
# 3      3.000000
# 4      2.000000
#          ...
# 120    4.000000
# 121    2.000000
# 122    3.028302
# 123    4.000000
# 124    3.028302
# Name: calories_day, Length: 125, dtype: float64

# %%
#Check the values.
data['calories_day'].value_counts()
# Out:
# 3.000000    63
# 4.000000    23
# 2.000000    20
# 3.028302    19
# Name: calories_day, dtype: int64

# %%
data.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430      3.028302           315.0
# 1  3.654       1          1               610      3.000000           420.0
# 2    3.3       1          1               720      4.000000           420.0
# 3    3.2       1          1               430      3.000000           420.0
# 4    3.5       1          1               720      2.000000           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...
